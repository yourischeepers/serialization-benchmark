// %% [markdown]
// # Charts generator
//
// This file uses Kotlin Notebooks and the Kandy library to generate charts that analyze and visualize the data from the benchmarks.

// %%
%useLatestDescriptors
%use dataframe
%use kandy(0.8.3)

import org.jetbrains.kotlinx.dataframe.api.*
import org.jetbrains.kotlinx.dataframe.io.readCSV

val raw = DataFrame.readCsv("results.csv")

val df = raw
    .rename("Param: complexity").into("Complexity")
    .rename("Param: size").into("Size")
    .rename("Score Error (99,9%)").into("ErrorMargin")
    .convert("Score")
    .with { it.toString().replace(",", ".").toDouble() }
    .convert("ErrorMargin")
    .with { it.toString().replace(",", ".").toDouble() }
    .convert("Size")
    .with { it.toString().toInt() }
    .convert("Benchmark")
    .with { if (it.toString().endsWith("gsonDeserialize")) "Gson" else "Kotlinx" }
    .select("Benchmark", "Complexity", "Size", "Score", "ErrorMargin", "Unit")
    .add("MicrosecondsPerOp") { 1_000_000.0 / ("Score"<Double>()) }


df
// Out:
//             <iframe onload="o_resize_iframe_out_14()" style="width:100%;" class="result_container" id="iframe_out_14" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
val complexDf = df.filter {
    Complexity == "complex"
}

complexDf.plot {
    line {
        x(Size)
        y(MicrosecondsPerOp)
        color(Benchmark)
    }

    points {
        x(Size)
        y(MicrosecondsPerOp)
        color(Benchmark)
    }

    layout {
        title = "Deserialization time (complex payloads)"
        xAxisLabel = "Object count"
        yAxisLabel = "Microseconds per operation"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;jCzEjr&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 600.0,
//        height: 400.0
//    };
//
// ...

// %%
complexDf.plot {
    line {
        x(Size)
        y(Score)
        color(Benchmark)
    }

    points {
        x(Size)
        y(Score)
        color(Benchmark)
    }

    layout {
        title = "Operations count (complex payloads)"
        xAxisLabel = "Object count"
        yAxisLabel = "Operations per second"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;dU3spT&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 600.0,
//        height: 400.0
//    };
//
// ...

// %%
val complexBarDf = complexDf
    .sortBy("Size")
    .add("Label") {
        "${Size} objects - ${Benchmark}"
    }
    .add("ErrorMin") {
        ("Score"<Double>()) - ("ErrorMargin"<Double>())
    }
    .add("ErrorMax") {
        ("Score"<Double>()) + ("ErrorMargin"<Double>())
    }

complexBarDf.plot {
    bars {
        x("Label") {
            axis.name = ""
        }
        y("Score")
        fillColor(Benchmark)
    }

    errorBars {
        x("Label")
        y("Score")
        yMin("ErrorMin")
        yMax("ErrorMax")
    }

    coordinatesTransformation =
        CoordinatesTransformation.cartesianFlipped()

    layout {
        title = "Complex payload throughput"
        yAxisLabel = "Operations per second"

        size = 900 to 500
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='500' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;LOWJfn&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 900.0,
//        height: 500.0
//    };
//
// ...

// %%
val complexBarDf = complexDf
    .sortBy("Size")
    .add("Label") {
        "${Size} objects - ${Benchmark}"
    }
    .add("ErrorMin") {
        val score = "Score"<Double>()
        val margin = "ErrorMargin"<Double>()
        1_000_000.0 / (score + margin)
    }
    .add("ErrorMax") {
        val score = "Score"<Double>()
        val margin = "ErrorMargin"<Double>()
        1_000_000.0 / (score - margin)
    }

complexBarDf.plot {
    bars {
        x("Label") {
            axis.name = ""
        }
        y("MicrosecondsPerOp")
        fillColor(Benchmark)
    }

    errorBars {
        x("Label")
        y("MicrosecondsPerOp")
        yMin("ErrorMin")
        yMax("ErrorMax")
    }

    coordinatesTransformation =
        CoordinatesTransformation.cartesianFlipped()

    layout {
        title = "Complex payload deserialization time"
        yAxisLabel = "Microseconds per operation"
        size = 900 to 500
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='500' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;MOljZZ&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 900.0,
//        height: 500.0
//    };
//
// ...

// %%
val bigDataDf = df.filter {
    Size == 10000
}

bigDataDf.plot {
    line {
        x(Complexity)
        y(MicrosecondsPerOp)
        color(Benchmark)
    }

    points {
        x(Complexity)
        y(MicrosecondsPerOp)
        color(Benchmark)
    }

    layout {
        title = "Deserialization time (10.000 objects)"
        xAxisLabel = "Object complexity"
        yAxisLabel = "Microseconds per operation"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;bBXxcs&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 600.0,
//        height: 400.0
//    };
//
// ...

// %%
bigDataDf.plot {
    line {
        x(Complexity)
        y(Score)
        color(Benchmark)
    }

    points {
        x(Complexity)
        y(Score)
        color(Benchmark)
    }

    layout {
        title = "Deserialization throughput (10.000 objects)"
        xAxisLabel = "Object complexity"
        yAxisLabel = "Microseconds per operation"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;nELYbm&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 600.0,
//        height: 400.0
//    };
//
// ...

// %%
val bigDataBarDf = bigDataDf
    .sortBy("Complexity")
    .add("Label") {
        "${Complexity} complexity - ${Benchmark}"
    }
    .add("ErrorMin") {
        ("Score"<Double>()) - ("ErrorMargin"<Double>())
    }
    .add("ErrorMax") {
        ("Score"<Double>()) + ("ErrorMargin"<Double>())
    }

bigDataBarDf.plot {
    bars {
        x("Label") {
            axis.name = ""
        }
        y("Score")
        fillColor(Benchmark)
    }

    errorBars {
        x("Label")
        y("Score")
        yMin("ErrorMin")
        yMax("ErrorMax")
    }

    coordinatesTransformation =
        CoordinatesTransformation.cartesianFlipped()

    layout {
        title = "Deserialization throughput (10.000 objects)"
        yAxisLabel = "Operations per second"

        size = 900 to 500
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='500' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;fZ28DY&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 900.0,
//        height: 500.0
//    };
//
// ...

// %%
val bigDataBarDf = bigDataDf
    .sortBy("Complexity")
    .add("Label") {
        "${Complexity} complexity - ${Benchmark}"
    }
    .add("ErrorMin") {
        val score = "Score"<Double>()
        val margin = "ErrorMargin"<Double>()
        1_000_000.0 / (score + margin)
    }
    .add("ErrorMax") {
        val score = "Score"<Double>()
        val margin = "ErrorMargin"<Double>()
        1_000_000.0 / (score - margin)
    }

bigDataBarDf.plot {
    bars {
        x("Label") {
            axis.name = ""
        }
        y("MicrosecondsPerOp")
        fillColor(Benchmark)
    }

    errorBars {
        x("Label")
        y("MicrosecondsPerOp")
        yMin("ErrorMin")
        yMax("ErrorMax")
    }

    coordinatesTransformation =
        CoordinatesTransformation.cartesianFlipped()

    layout {
        title = "Deserialization time (10.000 objects)"
        yAxisLabel = "Microseconds per operation"
        size = 900 to 500
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='500' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;Yq1w50&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 900.0,
//        height: 500.0
//    };
//
// ...

// %%
val combinedDf = df.add("Series") {
    "${Benchmark} - ${Complexity}"
}.sortBy("Complexity")

combinedDf.plot {
    line {
        x(Size)
        y(MicrosecondsPerOp)
        color("Series")
    }

    points {
        x(Size)
        y(MicrosecondsPerOp)
        color("Series")
    }

    layout {
        title = "Deserialization time by payload size"
        xAxisLabel = "Object count"
        yAxisLabel = "Microseconds per operation"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;xpoWYS&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 600.0,
//        height: 400.0
//    };
//
// ...

// %%
combinedDf.plot {
    line {
        x(Size)
        y(Score)
        color("Series")
    }

    points {
        x(Size)
        y(Score)
        color("Series")
    }

    layout {
        title = "Deserialization throughput by payload size"
        xAxisLabel = "Object count"
        yAxisLabel = "Operations per second"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;w3XgLf&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 600.0,
//        height: 400.0
//    };
//
// ...
